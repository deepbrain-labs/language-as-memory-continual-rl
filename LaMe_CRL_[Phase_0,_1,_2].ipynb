# %% [markdown]
# # **Phase - 0**

# %%
# !git clone https://github.com/deepbrain-labs/language-as-memory-continual-rl.git
# Out:
# Cloning into 'language-as-memory-continual-rl'...
# remote: Enumerating objects: 945, done.
# remote: Counting objects: 100% (82/82), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 945 (delta 40), reused 68 (delta 37), pack-reused 863 (from 1)
# Receiving objects: 100% (945/945), 1.07 MiB | 3.40 MiB/s, done.
# Resolving deltas: 100% (451/451), done.

# %%
# %cd language-as-memory-continual-rl
# Out:
# /content/language-as-memory-continual-rl

# %%
# !pip install -r requirements.txt
# !pip install gymnasium minigrid jsonlines trl peft
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 11.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.7/136.7 kB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.0/188.0 kB 16.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 MB 17.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 532.9/532.9 kB 37.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.5
#     Uninstalling protobuf-5.29.5:
#       Successfully uninstalled protobuf-5.29.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydf 0.14.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 4.25.8 which is incompatible.
# grain 0.2.15 requires protobuf>=5.28.3, but you have protobuf 4.25.8 which is incompatible.
# ...

# %%
# !python scripts/setup/validate_environment.py
# Out:
# Starting Phase 0 Environment Check...
#
# === GPU Check ===
# ✔ GPU Detected: Tesla T4
# ✔ Compatible GPU found.
# ✔ VRAM: 14.74 GB
#
# === Dependency Check ===
# 2026-01-26 10:14:29.780603: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769422469.800241    6436 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769422469.806154    6436 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1769422469.821178    6436 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python scripts/setup/test_model_loading.py
# Out:
# 2026-01-26 10:14:49.974111: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769422489.993677    6610 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769422489.999915    6610 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1769422490.014730    6610 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# # **Phase - 1**

# %%
# !python scripts/phase1/test_serialization.py
# Out:
# === State Serialization Test ===
# Checking determinism...
# ✔ Determinism passed.
# Text: You are carrying nothing. In the room, you see: yellow key, yellow door, green goal.
#
# Checking content...
# ✔ Content validation passed.
#
# ✔ PHASE 1: Serialization Test Passed.

# %%
# !python scripts/phase1/test_parser.py
# Out:
# === Subgoal Parser Test ===
# Input: 'Pick up the yellow key' -> Parsed: (pick, yellow, key)
# Input: 'pick yellow key' -> Parsed: (pick, yellow, key)
# Input: 'Go to the red door' -> Parsed: (goto, red, door)
# Input: 'reach the goal' -> Parsed: (goto, green, goal)
# Input: 'Open the blue door' -> Parsed: (open, blue, door)
# Input: 'Explore the room' -> Parsed: (no_op, any, none)
#
# ✔ PHASE 1: Parser Test Passed (Visual check).

# %%
# !python scripts/phase1/test_planner.py
# Out:
# === LLM Planner Test ===
# Using Phi2Planner (GPU Mode)
# 2026-01-26 10:16:13.241071: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769422573.272842    7043 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769422573.282613    7043 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1769422573.306063    7043 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python scripts/phase1/run_chain.py
# Out:
# === Phase 1: End-to-End Chain POC ===
# Using Phi2Planner (GPU Mode)
# 2026-01-26 10:16:59.959686: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769422619.981194    7273 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769422619.987043    7273 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1769422620.001798    7273 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# # **Phase - 2**

# %%
# !python src/data_gen/generate_traces.py
# Out:
# Generating data/expert_traces_train.json: 100% 200/200 [00:01<00:00, 134.16it/s]
# Saved 2668 steps to data/expert_traces_train.json
# Generating data/expert_traces_val.json: 100% 50/50 [00:00<00:00, 94.56it/s]
# Saved 663 steps to data/expert_traces_val.json
# Generating data/expert_traces_test.json: 100% 50/50 [00:00<00:00, 94.79it/s]
# Saved 860 steps to data/expert_traces_test.json

# %%
# !python src/data_gen/create_preference_pairs.py
# Out:
# Processing data/expert_traces_train.json -> data/dpo_train.jsonl
# Wrote 7369 pairs.
# Processing data/expert_traces_val.json -> data/dpo_val.jsonl
# Wrote 1794 pairs.
# Processing data/expert_traces_test.json -> data/dpo_test.jsonl
# Wrote 2372 pairs.

# %%
# !python src/data_gen/verify_dataset.py
# Out:
# Verifying data/dpo_train.jsonl...
# ✔ Scanned 7369 examples.
# ✔ Unique prompts: 2
# ✅ Integrity Check Passed.
#
# Verifying data/dpo_val.jsonl...
# ✔ Scanned 1794 examples.
# ✔ Unique prompts: 2
# ✅ Integrity Check Passed.
#
# Verifying data/dpo_test.jsonl...
# ✔ Scanned 2372 examples.
# ✔ Unique prompts: 2
# ✅ Integrity Check Passed.
#
# ✅ GLOBAL CHECK PASSED

# %% [markdown]
# ## **Pushing and Commiting**

# %%
# !git config --global user.name "Rishav Tewari"
# !git config --global user.email "rishabhhh.7@gmail.com"
# !git clone https://github.com/rishabhh-me/Continual_Reinforcement_Learning_with_Phi-2.git
# %cd Continual_Reinforcement_Learning_with_Phi-2
# Out:
# Cloning into 'Continual_Reinforcement_Learning_with_Phi-2'...
# remote: Enumerating objects: 654, done.
# remote: Counting objects: 100% (94/94), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 654 (delta 78), reused 75 (delta 75), pack-reused 560 (from 1)
# Receiving objects: 100% (654/654), 1022.51 KiB | 3.89 MiB/s, done.
# Resolving deltas: 100% (273/273), done.
# /content/language-as-memory-continual-rl/Continual_Reinforcement_Learning_with_Phi-2/Continual_Reinforcement_Learning_with_Phi-2/Continual_Reinforcement_Learning_with_Phi-2/Continual_Reinforcement_Learning_with_Phi-2/Continual_Reinforcement_Learning_with_Phi-2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp "/content/drive/MyDrive/LaMe_CRL_[Phase_0,_1,_2].ipynb" .
# Out:
# cp: cannot stat '/content/drive/MyDrive/LaMe_CRL_[Phase_0,_1,_2].ipynb': No such file or directory
